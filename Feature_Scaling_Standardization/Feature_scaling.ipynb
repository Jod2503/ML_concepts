# %% [markdown]
# ![image.png](attachment:731c7d78-d4cb-4df0-aac8-416e87ce10ef.png)

# %% [raw]
# # for eucleadian distance algos, in the figure we observe (y2-y1)<<<<(x2-x1).
# # is distance is calculated, there is minimal effect of age variable
# # to overcome this, we bring both the variables in a particular scale.
#
# Feature scaling is of 2 types
# 1. Standardization
# 2. Normalization
#    a)Min-max scaler
#    b) robust scaler

# %% [markdown]
# # standardization( z-score normalization)
# ![image.png](attachment:e972579c-b768-4efa-9322-abb290a0f480.png)

# %% [markdown]
# 99.7% values of Zi ranges from (-3,3)
# for zi:
# 1. mean(u)=0
# 2. standard deviation=1
#
# ![image.png](attachment:a29a4bba-900b-4a08-98b2-a37656ad36a6.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv('Social_Network_Ads.csv')
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
df=pd.read_csv('Social_Network_Ads.csv',usecols=['Age','EstimatedSalary','Purchased'])
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Purchased', axis=1),
                                                    df['Purchased'],
                                                    test_size=0.3,
                                                    random_state=0)

# %% [markdown]
# # Z-score normalization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# now we learn how values behave(mean sd etc)
scaler.fit(X_train)

# now we apply z score on the test and train cols
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
X_train
# Out:
#      Age  EstimatedSalary
# 92    26            15000
# 223   60           102000
# 234   38           112000
# 232   40           107000
# 377   42            53000
# ..   ...              ...
# 323   48            30000
# 192   29            43000
# 117   36            52000
# 47    27            54000
# 172   26           118000
#
# [280 rows x 2 columns]

# %%
X_train_scaled
# Out:
# array([[-1.1631724 , -1.5849703 ],
#        [ 2.17018137,  0.93098672],
#        [ 0.0133054 ,  1.22017719],
#        [ 0.20938504,  1.07558195],
#        [ 0.40546467, -0.48604654],
#        [-0.28081405, -0.31253226],
#        [ 0.99370357, -0.8330751 ],
#        [ 0.99370357,  1.8563962 ],
#        [ 0.0133054 ,  1.24909623],
#        [-0.86905295,  2.26126285],
#        [-1.1631724 , -1.5849703 ],
#        [ 2.17018137, -0.80415605],
#        [-1.35925203, -1.46929411],
#        [ 0.40546467,  2.2901819 ],
#        [ 0.79762394,  0.75747245],
#        [-0.96709276, -0.31253226],
#        [ 0.11134522,  0.75747245],
#        [-0.96709276,  0.55503912],
#        [ 0.30742485,  0.06341534],
#        [ 0.69958412, -1.26686079],
#        [-0.47689368, -0.0233418 ],
#        [-1.7514113 ,  0.3526058 ],
#        [-0.67297331,  0.12125343],
#        [ 0.40546467,  0.29476771],
#        [-0.28081405,  0.06341534],
#        [-0.47689368,  2.2901819 ],
#        [ 0.20938504,  0.03449629],
# ...

# %%
#convert this into a dataframe
X_train_scaled=pd.DataFrame(X_train_scaled,columns=X_train.columns)
X_test_scaled=pd.DataFrame(X_test_scaled,columns=X_test.columns)

# %%
X_test_scaled
# Out:
#           Age  EstimatedSalary
# 0   -0.771013         0.497201
# 1    0.013305        -0.572804
# 2   -0.280814         0.150172
# 3   -0.771013         0.265849
# 4   -0.280814        -0.572804
# ..        ...              ...
# 115  1.091743        -0.139018
# 116  0.699584         1.769639
# 117 -0.672973         0.555039
# 118  0.797624         0.352606
# 119  0.895664        -0.543885
#
# [120 rows x 2 columns]

# %%
X_train.describe()
# Out:
#               Age  EstimatedSalary
# count  280.000000       280.000000
# mean    37.864286     69807.142857
# std     10.218201     34641.201654
# min     18.000000     15000.000000
# 25%     30.000000     43000.000000
# 50%     37.000000     70500.000000
# 75%     46.000000     88000.000000
# max     60.000000    150000.000000

# %%
np.round(X_train_scaled.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean     0.0              0.0
# std      1.0              1.0
# min     -1.9             -1.6
# 25%     -0.8             -0.8
# 50%     -0.1              0.0
# 75%      0.8              0.5
# max      2.2              2.3

# %%
X_train_scaled
# Out:
#           Age  EstimatedSalary
# 0   -1.163172        -1.584970
# 1    2.170181         0.930987
# 2    0.013305         1.220177
# 3    0.209385         1.075582
# 4    0.405465        -0.486047
# ..        ...              ...
# 275  0.993704        -1.151185
# 276 -0.869053        -0.775237
# 277 -0.182774        -0.514966
# 278 -1.065133        -0.457127
# 279 -1.163172         1.393691
#
# [280 rows x 2 columns]

# %%
sns.scatterplot(x= X_train['Age'],y= X_train['EstimatedSalary'])
plt.title('without scaling')
plt.show()

# %%
sns.scatterplot(x=X_train_scaled['Age'],y=X_train_scaled['EstimatedSalary'],color='red')
plt.title('New scaled plot')
plt.show()
# we notice shape of the data remains same. only the scale changes(data centrered)

# %%
# make probability density plots
sns.distplot(x= X_train['Age'],hist=False)
sns.distplot(x= X_train['EstimatedSalary'],hist=False)
plt.title('W/o Scaling')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_1176\2810654286.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x= X_train['Age'],hist=False)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_1176\2810654286.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# after scaling
sns.distplot(x= X_train_scaled['Age'],hist=False)
sns.distplot(x= X_train_scaled['EstimatedSalary'],hist=False)
plt.title('With Scaling')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_1176\664267701.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x= X_train_scaled['Age'],hist=False)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_1176\664267701.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr_scaled=LogisticRegression()

# %%
lr.fit(X_train,y_train)
#model is fitted with x train
lr_scaled.fit(X_train_scaled,y_train)
# model is fit with scaled x value and we need to find y predicted value
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(X_test)
y_pred_scaled=lr_scaled.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.875

# %%
accuracy_score(y_test,y_pred_scaled)
# Out:
# 0.8666666666666667
